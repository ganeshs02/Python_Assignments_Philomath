# %%
#Cleaning Data in Pandas 

import pandas as pd

# %%
#

df = pd.read_excel(r"C:\Users\Ganseh\Downloads\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#DROP_Duplicates - To drop the duplicate values

df = df.drop_duplicates() #to remove the duplicates
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#DROP - to drop the columns

df = df.drop(columns="Not_Useful_Column") #used to drop the unwanted column.
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#STRIP - to strip the column element. / replace 
#to strip the elements from righ , left or both the sides.
#rstrip - right , lstrip - lef side, strip - both the sides.
#you should mention the the column otherwise it will apply to all the values.

#df['Last_Name'] = df['Last_Name'].str.lstrip("...") #to remove from left hand side

#df['Last_Name'] = df['Last_Name'].str.strip("/")

df['Last_Name'] = df['Last_Name'].str.strip("123./_") #to remove from the both the sides
df
#you have to combine the values you want to remove just like above
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#REPLACE - its jsut like the strip but it replaces with another value


#Working with the Phone numbers.

#df['Phone_Number'] = df['Phone_Number'].str.replace("/","",regex=False) #replaces '/' by ''
___________________

#df['Phone_Number'] = df['Phone_Number'].str.replace("|","",regex=False) #replaces '|' by ''

#df['Phone_Number'] = df['Phone_Number'].str.replace("-","",regex=False) #replaces '|' by ''

#df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','') #will replace all the values with empty.

#df["Phone_Number"] = df["Phone_Number"].apply(lambda x:str(x)) #to covert phone number in string

#df = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10]) #it applies '-' after perticular numbers

#df["Phone_Number"].str.replace('nan--','')

#df["Phone_Number"] = df["Phone_Number"].str.replace('na--','') #to replace 'na--' with ''
#df = df.str.replace('Na--','')
#df = df.str.replace('nan--','')

df

# %%
df

#df = df["Address"].str.split(',', 3 , expand=True) #expands into columns 

#df[['Street_Address', "State", "Zip_Code"]] = df.str.split(',',expand=True) #splits the address in the specified column names.

# %%
#df = df['Paying Customer'].str.replace("Yes","Y") replaces 'Yes' to "Y"
#df = df["Paying Customer"].str.replace("No", "N")
df

# %%
#df = df.replace('N/a',"")

#df = df.replace('Na',"")

#To fill the empty values 
df.fillna('') #replaces NaN with empty.
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# ...

# %%
#Now we are going to remove the entire row which have the value for the 'do not call' column.

for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == "Y": #to look by index we use 'loc'
        df.drop(x, inplace=True)
#this code removed the row where 'don not call' is 'Y'

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# ...

# %%
#to replace the empty values in the phone number column we will drop it


for x in df.index:
    if df.loc[x, "Phone_Number"] == "": #to look by index we use 'loc'
        df.drop(x, inplace=True)

#OR another way to drop null values

#df.dropna(subset=("Phone_Number"), inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 19        1020     Anakin   Skywalker  876|678|3469
# ...

# %%
#To reset the index 

df.reset_index(drop=True) #drops original index and gives us new index
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1005        Jon        Snow  876|678|3469
# 4         1006        Ron     Swanson  304-762-2467
# 5         1007       Jeff      Winger           NaN
# 6         1008   Sherlock      Holmes  876|678|3469
# 7         1010      Peter      Parker  123-545-5421
# 8         1011    Samwise      Gamgee           NaN
# 9         1012      Harry      Potter    7066950392
# 10        1013        Don      Draper  123-543-2345
# 11        1014     Leslie       Knope  876|678|3469
# 12        1015       Toby  Flenderson  304-762-2467
# 13        1016        Ron     Weasley  123-545-5421
# 14        1017   Michael        Scott  123/643/9775
# 15        1018      Clark        Kent    7066950392
# 16        1020     Anakin   Skywalker  876|678|3469
# ...
